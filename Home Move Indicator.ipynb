# %%
import numpy as np
import pandas as pd
from collections import OrderedDict 

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
from zoopla import Zoopla

zoopla = Zoopla(api_key='gcstpjxbj29s2nzkmr9jnkgg')

# %%
# %%html
# <center><img src="https://www.zoopla.co.uk/static/images/mashery/powered-by-zoopla-150x73.png" width="150" height="73" title="Property information powered by Zoopla" alt="Property information powered by Zoopla" border="0"></center>
# Out:
# <center><img src="https://www.zoopla.co.uk/static/images/mashery/powered-by-zoopla-150x73.png" width="150" height="73" title="Property information powered by Zoopla" alt="Property information powered by Zoopla" border="0"></center>

# %%
import plotly.plotly as py
import plotly.graph_objs as go

# %%
import postcodes_io_api
api  = postcodes_io_api.Api(debug_http=True)

# %%
# %%time
column_list=['listing_id','longitude','latitude','first_published_date','last_published_date','listing_status','property_type']
data=[]
for status in ['sale','rent']:
    page_num=1
    while 1:
        search = zoopla.property_listings({'listing_status': status,'area': 'BN3','include_sold':'1','include_rented':'1',
                                           'order_by':'age','ordering':'descending','page_number':page_num,'page_size':100})
        if(page_num==1):
            nresults=search.result_count
            npages=np.ceil(nresults/100)
        for result in search.listing:
            result_dict=OrderedDict((key,result[key]) for key in column_list)
            result_dict['outcode']='BN3'
            result_dict['postcode']=api.get_nearest_postcodes_for_coordinates(latitude=result.latitude,longitude=result.longitude,limit=1)['result'][0]['postcode']
            data.append(pd.DataFrame(result_dict,index=[0]))
        if(page_num>=npages):
            break
        else:
            page_num+=1
data=pd.concat(data)
col_list=['Listing ID','Longitude','Latitude','First Published Date','Last Published Date','Listing Status','Property Type','Outcode','Postcode']
data.rename(columns=dict(zip(data.columns,col_list)),inplace=True)
data.reset_index(drop=True,inplace=True)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.zoopla.co.uk:80
# send: b'GET /api/v1/property_listings.json?listing_status=sale&area=BN3&include_sold=1&include_rented=1&order_by=age&ordering=descending&page_number=1&page_size=100&api_key=gcstpjxbj29s2nzkmr9jnkgg HTTP/1.1\r\nHost: api.zoopla.co.uk\r\nUser-Agent: python-requests/2.21.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\n\r\n'
# DEBUG:urllib3.connectionpool:http://api.zoopla.co.uk:80 "GET /api/v1/property_listings.json?listing_status=sale&area=BN3&include_sold=1&include_rented=1&order_by=age&ordering=descending&page_number=1&page_size=100&api_key=gcstpjxbj29s2nzkmr9jnkgg HTTP/1.1" 200 None
# reply: 'HTTP/1.1 200 OK\r\n'
# header: Content-Type: application/json; charset=utf-8
# header: Date: Sun, 03 Mar 2019 03:49:43 GMT
# header: Server: nginx
# header: transfer-encoding: chunked
# header: Connection: keep-alive
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.postcodes.io:80
# DEBUG:urllib3.connectionpool:http://api.postcodes.io:80 "GET /postcodes?latitude=50.824722&longitude=-0.166909&limit=1 HTTP/1.1" 200 852
# DEBUG:urllib3.connectionpool:http://api.postcodes.io:80 "GET /postcodes?latitude=50.824722&longitude=-0.166909&limit=1 HTTP/1.1" 200 852
# DEBUG:urllib3.connectionpool:http://api.postcodes.io:80 "GET /postcodes?latitude=50.82802&longitude=-0.165544&limit=1 HTTP/1.1" 200 852
# DEBUG:urllib3.connectionpool:http://api.postcodes.io:80 "GET /postcodes?latitude=50.833515&longitude=-0.172912&limit=1 HTTP/1.1" 200 848
# DEBUG:urllib3.connectionpool:http://api.postcodes.io:80 "GET /postcodes?latitude=50.823452&longitude=-0.156423&limit=1 HTTP/1.1" 200 853
# send: b'GET /postcodes?latitude=50.824722&longitude=-0.166909&limit=1 HTTP/1.1\r\nHost: api.postcodes.io\r\nUser-Agent: python-requests/2.21.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\n\r\n'
# reply: 'HTTP/1.1 200 OK\r\n'
# header: Server: nginx/1.14.0
# header: Date: Sun, 03 Mar 2019 03:49:44 GMT
# header: Content-Type: application/json; charset=utf-8
# header: Content-Length: 852
# header: Connection: keep-alive
# header: Access-Control-Allow-Origin: *
# header: ETag: W/"354-lSECcffPYh5R6TCpIXXpuEj2Dpk"
# header: X-GNU: Michael J Blanchard
# send: b'GET /postcodes?latitude=50.824722&longitude=-0.166909&limit=1 HTTP/1.1\r\nHost: api.postcodes.io\r\nUser-Agent: python-requests/2.21.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\n\r\n'
# reply: 'HTTP/1.1 200 OK\r\n'
# header: Server: nginx/1.14.0
# header: Date: Sun, 03 Mar 2019 03:49:44 GMT
# header: Content-Type: application/json; charset=utf-8
# header: Content-Length: 852
# header: Connection: keep-alive
# header: Access-Control-Allow-Origin: *
# header: ETag: W/"354-lSECcffPYh5R6TCpIXXpuEj2Dpk"
# header: X-GNU: Michael J Blanchard
# send: b'GET /postcodes?latitude=50.82802&longitude=-0.165544&limit=1 HTTP/1.1\r\nHost: api.postcodes.io\r\nUser-Agent: python-requests/2.21.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\n\r\n'
# reply: 'HTTP/1.1 200 OK\r\n'
# header: Server: nginx/1.14.0
# header: Date: Sun, 03 Mar 2019 03:49:44 GMT
# header: Content-Type: application/json; charset=utf-8
# header: Content-Length: 852
# header: Connection: keep-alive
# header: Access-Control-Allow-Origin: *
# header: ETag: W/"354-Adwlkz/BpxTwHx1gWuRVcsFMFAk"
# header: X-GNU: Michael J Blanchard
# send: b'GET /postcodes?latitude=50.833515&longitude=-0.172912&limit=1 HTTP/1.1\r\nHost: api.postcodes.io\r\nUser-Agent: python-requests/2.21.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\n\r\n'
# reply: 'HTTP/1.1 200 OK\r\n'
# header: Server: nginx/1.14.0
# header: Date: Sun, 03 Mar 2019 03:49:44 GMT
# header: Content-Type: application/json; charset=utf-8
# header: Content-Length: 848
# header: Connection: keep-alive
# header: Access-Control-Allow-Origin: *
# header: ETag: W/"350-sxZarWcvHu+1jxpEgfkmTaBKSIM"
# header: X-GNU: Michael J Blanchard
# send: b'GET /postcodes?latitude=50.823452&longitude=-0.156423&limit=1 HTTP/1.1\r\nHost: api.postcodes.io\r\nUser-Agent: python-requests/2.21.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\n\r\n'
# reply: 'HTTP/1.1 200 OK\r\n'
# header: Server: nginx/1.14.0
# header: Date: Sun, 03 Mar 2019 03:49:44 GMT
# header: Content-Type: application/json; charset=utf-8
# header: Content-Length: 853
# header: Connection: keep-alive
# header: Access-Control-Allow-Origin: *
# header: ETag: W/"355-S/YzsqcqejVbb91HbJaKWHx+2rA"
# header: X-GNU: Michael J Blanchard
# send: b'GET /postcodes?latitude=50.84727&longitude=-0.205162&limit=1 HTTP/1.1\r\nHost: api.postcodes.io\r\nUser-Agent: python-requests/2.21.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\n\r\n'
# DEBUG:urllib3.connectionpool:http://api.postcodes.io:80 "GET /postcodes?latitude=50
# DEBUG:urllib3.connectionpool:http://api.postcodes.io:80 "GET /postcodes?latitude=50.829475&longitude=-0.19011&limit=1 HTTP/1.1" 200 849
# DEBUG:urllib3.connectionpool:http://api.postcodes.io:80 "GET /postcodes?latitude=50.85241&longitude=-0.169972&limit=1 HTTP/1.1" 200 848
# DEBUG:urllib3.connectionpool:http://api.postcodes.io:80 "GET /postcodes?latitude=50.832905&longitude=-0.17775&limit=1 HTTP/1.1" 200 849
# DEBUG:urllib3.connectionpool:http://api.postcodes.io:80 "GET /postcodes?latitude=50.833176&longitude=-0.171321&limit=1 HTTP/1.1" 200 848
# reply: 'HTTP/1.1 200 OK\r\n'
# header: Server: nginx/1.14.0
# header: Date: Sun, 03 Mar 2019 03:50:28 GMT
# header: Content-Type: application/json; charset=utf-8
# header: Content-Length: 850
# header: Connection: keep-alive
# header: Access-Control-Allow-Origin: *
# header: ETag: W/"352-lm3s4+//3Z4RqiqRw7H/WP6pWLo"
# header: X-GNU: Michael J Blanchard
# send: b'GET /postcodes?latitude=50.833996&longitude=-0.162356&limit=1 HTTP/1.1\r\nHost: api.postcodes.io\r\nUser-Agent: python-requests/2.21.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\n\r\n'
# reply: 'HTTP/1.1 200 OK\r\n'
# header: Server: nginx/1.14.0
# header: Date: Sun, 03 Mar 2019 03:50:28 GMT
# header: Content-Type: application/json; charset=utf-8
# header: Content-Length: 839
# header: Connection: keep-alive
# header: Access-Control-Allow-Origin: *
# header: ETag: W/"347-Coj+KcZ1GwJ/t94uo68Wfsv6FYE"
# header: X-GNU: Michael J Blanchard
# send: b'GET /postcodes?latitude=50.829475&longitude=-0.19011&limit=1 HTTP/1.1\r\nHost: api.postcodes.io\r\nUser-Agent: python-requests/2.21.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\n\r\n'
# reply: 'HTTP/1.1 200 OK\r\n'
# header: Server: nginx/1.14.0
# header: Date: Sun, 03 Mar 2019 03:50:28 GMT
# header: Content-Type: application/json; charset=utf-8
# header: Content-Length: 849
# header: Connection: keep-alive
# header: Access-Control-Allow-Origin: *
# header: ETag: W/"351-krU216ay4De7lXXX5tLAOJau3yg"
# header: X-GNU: Michael J Blanchard
# send: b'GET /postcodes?latitude=50.85241&longitude=-0.169972&limit=1 HTTP/1.1\r\nHost: api.postcodes.io\r\nUser-Agent: python-requests/2.21.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\n\r\n'
# reply: 'HTTP/1.1 200 OK\r\n'
# header: Server: nginx/1.14.0
# header: Date: Sun, 03 Mar 2019 03:50:28 GMT
# header: Content-Type: application/json; charset=utf-8
# header: Content-Length: 848
# header: Connection: keep-alive
# header: Access-Control-Allow-Origin: *
# header: ETag: W/"350-NCgUDY9sNfYHsfxngFdcoPvh5HE"
# header: X-GNU: Michael J Blanchard
# send: b'GET /postcodes?latitude=50.832905&longitude=-0.17775&limit=1 HTTP/1.1\r\nHost: api.postcodes.io\r\nUser-Agent: python-requests/2.21.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\n\r\n'
# reply: 'HTTP/1.1 200 OK\r\n'
# header: Server: nginx/1.14.0
# header: Date: Sun, 03 Mar 2019 03:50:28 GMT
# header: Content-Type: application/json; charset=utf-8
# header: Content-Length: 849
# header: Connection: keep-alive
# header: Access-Control-Allow-Origin: *
# header: ETag: W/"351-GiXyVFdKbl8+Qm9VX27+6avphj4"
# header: X-GNU: Michael J Blanchard
# send: b'GET /postcodes?latitude=50.833176&longitude=-0.171321&limit=1 HTTP/1.1\r\nHost: api.postcodes.io\r\nUser-Agent: python-requests/2.21.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\n\r\n'
# reply: 'HTTP/1.1 200 OK\r\n'
# header: Server: nginx/1.14.0
# header: Date: Sun, 03 Mar 2019 03:50:28 GMT
# header: Content-Type: application/json; charset=utf-8
# header: Content-Length: 848
# header: Connection: keep-alive
# header: Access-Control-Allow-Origin: *
# header: ETag: W/"350-PLBypTVLp4yS2HHyKEL5FHUFodk"
# header: X-GNU: Michael J Blanchard
# CPU times: user 11 s, sys: 2.45 s, total: 13.4 s
# Wall time: 46.7 s

# %%
# %%time
column_list=['listing_id','listing_status']
data2=[]
for status in ['sale','rent']:
    page_num=1
    while 1:
        search = zoopla.property_listings({'listing_status': status,'area': 'BN3',
                                           'order_by':'age','ordering':'descending','page_number':page_num,'page_size':100})
        if(page_num==1):
            nresults=search.result_count
            npages=np.ceil(nresults/100)
        for result in search.listing:
            result_dict=OrderedDict((key,result[key]) for key in column_list)
            data2.append(pd.DataFrame(result_dict,index=[0]))
        if(page_num>=npages):
            break
        else:
            page_num+=1
data2=pd.concat(data2)
col_list=['Listing ID','Listing Status']
data2.rename(columns=dict(zip(data2.columns,col_list)),inplace=True)
data2.reset_index(drop=True,inplace=True)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.zoopla.co.uk:80
# send: b'GET /api/v1/property_listings.json?listing_status=sale&area=BN3&order_by=age&ordering=descending&page_number=1&page_size=100&api_key=gcstpjxbj29s2nzkmr9jnkgg HTTP/1.1\r\nHost: api.zoopla.co.uk\r\nUser-Agent: python-requests/2.21.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\n\r\n'
# DEBUG:urllib3.connectionpool:http://api.zoopla.co.uk:80 "GET /api/v1/property_listings.json?listing_status=sale&area=BN3&order_by=age&ordering=descending&page_number=1&page_size=100&api_key=gcstpjxbj29s2nzkmr9jnkgg HTTP/1.1" 200 None
# reply: 'HTTP/1.1 200 OK\r\n'
# header: Content-Type: application/json; charset=utf-8
# header: Date: Sun, 03 Mar 2019 03:50:30 GMT
# header: Server: nginx
# header: transfer-encoding: chunked
# header: Connection: keep-alive
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.zoopla.co.uk:80
# send: b'GET /api/v1/property_listings.json?listing_status=sale&area=BN3&order_by=age&ordering=descending&page_number=2&page_size=100&api_key=gcstpjxbj29s2nzkmr9jnkgg HTTP/1.1\r\nHost: api.zoopla.co.uk\r\nUser-Agent: python-requests/2.21.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\n\r\n'
# DEBUG:urllib3.connectionpool:http://api.zoopla.co.uk:80 "GET /api/v1/property_listings.json?listing_status=sale&area=BN3&order_by=age&ordering=descending&page_number=2&page_size=100&api_key=gcstpjxbj29s2nzkmr9jnkgg HTTP/1.1" 200 None
# reply: 'HTTP/1.1 200 OK\r\n'
# header: Content-Type: application/json; charset=utf-8
# header: Date: Sun, 03 Mar 2019 03:50:31 GMT
# header: Server: nginx
# header: transfer-encoding: chunked
# header: Connection: keep-alive
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.zoopla.co.uk:80
# send: b'GET /api/v1/property_listings.json?listing_status=sale&area=BN3&order_by=age&ordering=descending&page_number=3&page_size=100&api_key=gcstpjxbj29s2nzkmr9jnkgg HTTP/1.1\r\nHost: api.zoopla.co.uk\r\nUser-Agent: python-requests/2.21.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\n\r\n'
# DEBUG:urllib3.connectionpool:http://api.zoopla.co.uk:80 "GET /api/v1/property_listings.json?listing_status=sale&area=BN3&order_by=age&ordering=descending&page_number=3&page_size=100&api_key=gcstpjxbj29s2nzkmr9jnkgg HTTP/1.1" 200 None
# reply: 'HTTP/1.1 200 OK\r\n'
# header: Content-Type: application/json; charset=utf-8
# header: Date: Sun, 03 Mar 2019 03:50:33 GMT
# header: Server: nginx
# header: transfer-encoding: chunked
# header: Connection: keep-alive
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.zoopla.co.uk:80
# send: b'GET /api/v1/property_listings.json?listing_status=sale&area=BN3&order_by=age&ordering=descending&page_number=4&page_size=100&api_key=gcstpjxbj29s2nzkmr9jnkgg HTTP/1.1\r\nHost: api.zoopla.co.uk\r\nUser-Agent: python-requests/2.21.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\n\r\n'
# DEBUG:urllib3.connectionpool:http://api.zoopla.co.uk:80 "GET /api/v1/property_listings.json?listing_status=sale&area=BN3&order_by=age&ordering=descending&page_number=4&page_size=100&api_key=gcstpjxbj29s2nzkmr9jnkgg HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.zoopla.co.uk:80
# reply: 'HTTP/1.1 200 OK\r\n'
# header: Content-Type: application/json; charset=utf-8
# header: Date: Sun, 03 Mar 2019 03:50:34 GMT
# header: Server: nginx
# header: transfer-encoding: chunked
# header: Connection: keep-alive
# send: b'GET /api/v1/property_listings.json?listing_status=rent&area=BN3&order_by=age&ordering=descending&page_number=1&page_size=100&api_key=gcstpjxbj29s2nzkmr9jnkgg HTTP/1.1\r\nHost: api.zoopla.co.uk\r\nUser-Agent: python-requests/2.21.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\n\r\n'
# DEBUG:urllib3.connectionpool:http://api.zoopla.co.uk:80 "GET /api/v1/property_listings.json?listing_status=rent&area=BN3&order_by=age&ordering=descending&page_number=1&page_size=100&api_key=gcstpjxbj29s2nzkmr9jnkgg HTTP/1.1" 200 None
# reply: 'HTTP/1.1 200 OK\r\n'
# header: Content-Type: application/json; charset=utf-8
# header: Date: Sun, 03 Mar 2019 03:50:35 GMT
# header: Server: nginx
# header: transfer-encoding: chunked
# header: Connection: keep-alive
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.zoopla.co.uk:80
# send: b'GET /api/v1/property_listings.json?listing_status=rent&area=BN3&order_by=age&ordering=descending&page_number=2&page_size=100&api_key=gcstpjxbj29s2nzkmr9jnkgg HTTP/1.1\r\nHost: api.zoopla.co.uk\r\nUser-Agent: python-requests/2.21.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\n\r\n'
# DEBUG:urllib3.connectionpool:http://api.zoopla.co.uk:80 "GET /api/v1/property_listings.json?listing_status=rent&area=BN3&order_by=age&ordering=descending&page_number=2&page_size=100&api_key=gcstpjxbj29s2nzkmr9jnkgg HTTP/1.1" 200 None
# reply: 'HTTP/1.1 200 OK\r\n'
# header: Content-Type: application/json; charset=utf-8
# header: Date: Sun, 03 Mar 2019 03:50:36 GMT
# header: Server: nginx
# header: transfer-encoding: chunked
# header: Connection: keep-alive
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.zoopla.co.uk:80
# send: b'GET /api/v1/property_listings.json?listing_status=rent&area=BN3&order_by=age&ordering=descending&page_number=3&page_size=100&api_key=gcstpjxbj29s2nzkmr9jnkgg HTTP/1.1\r\nHost: api.zoopla.co.uk\r\nUser-Agent: python-requests/2.21.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\n\r\n'
# DEBUG:urllib3.connectionpool:http://api.zoopla.co.uk:80 "GET /api/v1/property_listings.json?listing_status=rent&area=BN3&order_by=age&ordering=descending&page_number=3&page_size=100&api_key=gcstpjxbj29s2nzkmr9jnkgg HTTP/1.1" 200 None
# reply: 'HTTP/1.1 200 OK\r\n'
# header: Content-Type: application/json; charset=utf-8
# header: Date: Sun, 03 Mar 2019 03:50:38 GMT
# header: Server: nginx
# header: transfer-encoding: chunked
# header: Connection: keep-alive
# CPU times: user 627 ms, sys: 69.8 ms, total: 696 ms
# Wall time: 9.59 s

# %% [markdown]
# Listing ID is unique value and therefore can be used to match between the two dataframes.

# %%
len(data['Listing ID'].unique())==data.shape[0]
# Out:
# True

# %%
data.loc[(~data['Listing ID'].isin(data2['Listing ID'])&(data['Listing Status']=='sale')), 'Listing Status'] = 'sold'
data.loc[(~data['Listing ID'].isin(data2['Listing ID'])&(data['Listing Status']=='rent')), 'Listing Status'] = 'rented'

# %%
text=[]
for text_dict in data[['Listing ID','First Published Date','Last Published Date', 'Listing Status', 'Property Type', 'Postcode']].to_dict('records'):
    text.append('\n'.join([': '.join(map(str,item)) for item in text_dict.items()]))
data['Description text']=text

# %% [markdown]
# ### Alternative method for creating `Description Text` column:
# _Time performance to be compared later_

# %% [raw]
# def format_text(df):
#     return '\n'.join(i+': '+str(df[i]) for i in ['Listing ID','First Published Date','Last Published Date', 'Listing Status', 'Property Type', 'Postcode'])

# %% [raw]
# data['Description text']=data.apply(format_text,axis=1)

# %%
split_data=[]
for i in ['sale','rent','sold','rented']:
    split_data.append(data[data['Listing Status']==i])

# %%
cm=['#D62728','#1F77B4','#ED9999','#9AC0CD']
legend=['For Sale','For rent','Sold','Rented']

# %%
mapbox_access_token = 'pk.eyJ1IjoiYXJ1MjYxMiIsImEiOiJjanMwanVvcHgxZjg2M3luMTk2c2Z1ZnNvIn0.LJrZfEMS-mfe8nIOVqLziA'

plot_data = [
    go.Scattermapbox(
        lon=list(split_data[i]['Longitude']),
        lat=list(split_data[i]['Latitude']),
        mode='markers',
        marker=dict(
            size=9,
            color=cm[i]
        ),
        text=list(split_data[i]['Description text']),
        name=legend[i],
        showlegend=True
    ) for i in range(len(split_data)-1,-1,-1)
]

layout = go.Layout(
    autosize=True,
    hovermode='closest',
    mapbox=dict(
        accesstoken=mapbox_access_token,
        bearing=0,
        center=dict(
            lon=data['Longitude'].sum()/float(len(data['Longitude'])),
            lat=data['Latitude'].sum()/float(len(data['Latitude']))
        ),
        pitch=0,
        zoom=10
    ),
)

fig = dict(data=plot_data, layout=layout)
py.iplot(fig, filename='Multiple Mapbox')
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): plot.ly:443
# send: b'POST /clientresp HTTP/1.1\r\nHost: plot.ly\r\nUser-Agent: python-requests/2.21.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\nContent-Length: 244503\r\nContent-Type: application/x-www-form-urlencoded\r\n\r\n'
# send: b'platform=python&version=3.6.1&args=%5B%7B%22lat%22%3A+%5B50.829918%2C+50.85219%2C+50.826336%2C+50.832226%2C+50.829357%2C+50.833405%2C+50.826%2C+50.82663%2C+50.8309%2C+50.82663%2C+50.83116%2C+50.827663%2C+50.82927%2C+50.831062%2C+50.824833%2C+50.82689%2C+50.82939%2C+50.82771%2C+50.82659%2C+50.823627%2C+50.830227%2C+50.832462%2C+50.83481%2C+50.82519%2C+50.832428%2C+50.834835%2C+50.824818%2C+50.8334%2C+50.83191%2C+50.828392%2C+50.827984%2C+50.830227%2C+50.837116%2C+50.826126%2C+50.83364%2C+50.829857%2C+50.826355%2C+50.834244%2C+50.82745%2C+50.830173%2C+50.836243%2C+50.827152%2C+50.82622%2C+50.826267%2C+50.82976%2C+50.828392%2C+50.833996%2C+50.825283%2C+50.832333%2C+50.830647%2C+50.828144%2C+50.830765%2C+50.82627%2C+50.826786%2C+50.82548%2C+50.82704%2C+50.829063%2C+
%2C+-0.200586%2C+-0.157236%2C+-0.19011%5D%2C+%22marker%22%3A+%7B%22color%22%3A+%22%239AC0CD%22%2C+%22size%22%3A+9%7D%2C+%22mode%22%3A+%22markers%22%2C+%22name%22%3A+%22Rented%22%2C+%22showlegend%22%3A+true%2C+%22text%22%3A+%5B%22Listing+ID%3A+50640072%3Cbr%3EFirst+Published+Date%3A+2019-02-27+22%3A01%3A30%3Cbr%3ELast+Published+Date%3A+2019-03-02+22%3A06%3A22%3Cbr%3EListing+Status%3A+rented%3Cbr%3EProperty+Type%3A+%3Cbr%3EPostcode%3A+BN3+3DJ%22%2C+%22Listing+ID%3A+50607868%3Cbr%3EFirst+Published+Date%3A+2019-02-25+21%3A36%3A00%3Cbr%3ELast+Published+Date%3A+2019-03-02+21%3A43%3A21%3Cbr%3EListing+Status%3A+rented%3Cbr%3EProperty+Type%3A+Flat%3Cbr%3EPostcode%3A+BN3+8BJ%22%2C+%22Listing+ID%3A+50598613%3Cbr%3EFirst+Published+Date%3A+2019-02-25+09%3A20%3A59%3Cbr%3ELast+Published+Date%3A+2019-03-01+16%3A19%3A30%3Cbr%3EListing+Status%3A+rented%3Cbr%3EProperty+Type%3A+Studio%3Cbr%3EPostcode%3A+BN3+4GL%22%2C+%22Listing+ID%3A+50584749%3Cbr%3EFirst+Published+Date%3A+2019-02-22+15%3A38%3A29%3Cbr%3ELast+Publis ...
# DEBUG:urllib3.connectionpool:https://plot.ly:443 "POST /clientresp HTTP/1.1" 200 None
# reply: 'HTTP/1.1 200 OK\r\n'
# header: Server: nginx
# header: Date: Sun, 03 Mar 2019 03:50:41 GMT
# header: Content-Type: application/json
# header: Vary: Accept-Encoding
# header: Vary: Accept-Encoding
# header: strict-transport-security: max-age=31536000; includeSubDomains; preload
# header: x-content-type-options: nosniff
# header: x-xss-protection: 1; mode=block
# header: X-Frame-Options: SAMEORIGIN
# header: Content-Language: en
# header: Set-Cookie: plotly_csrf_pr=5I4eUkoE0r79DwJvVFAfwOoz3hCBoTzo; Domain=.plot.ly; expires=Tue, 03-Mar-2020 03:50:41 GMT; Max-Age=31622400; Path=/; Secure
# header: Set-Cookie: plotly_csrf_pr=5I4eUkoE0r79DwJvVFAfwOoz3hCBoTzo; Domain=.plot.ly; expires=Tue, 03-Mar-2020 03:50:41 GMT; Max-Age=31622400; Path=/; Secure
# header: Set-Cookie: plotly_csrf_pr=5I4eUkoE0r79DwJvVFAfwOoz3hCBoTzo; Domain=.plot.ly; expires=Tue, 03-Mar-2020 03:50:41 GMT; Max-Age=31622400; Path=/; Secure
# header: Content-Encoding: gzip
# header: Via: 1.1 google
# header: Set-Cookie: plotly_csrf_pr=5I4eUkoE0r79DwJvVFAfwOoz3hCBoTzo; Domain=.plot.ly; expires=Tue, 03-Mar-2020 03:50:41 GMT; Max-Age=31622400; Path=/; Secure
# header: Alt-Svc: clear
# header: Transfer-Encoding: chunked
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~Aru2612/2.embed" height="525px" width="100%"></iframe>
